# %%
x=1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
from anndata import AnnData
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap
from plottable.plots import bar

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

def cmap_map(function, cmap):
    """ Applies function (which should operate on vectors of shape 3: [r, g, b]), on colormap cmap.
    This routine will break any discontinuous points in a colormap.
    """
    cdict = cmap._segmentdata
    step_dict = {}
    # Firt get the list of points where the segments start or end
    for key in ('red', 'green', 'blue'):
        step_dict[key] = list(map(lambda x: x[0], cdict[key]))
    step_list = sum(step_dict.values(), [])
    step_list = np.array(list(set(step_list)))
    # Then compute the LUT, and apply the function to the LUT
    reduced_cmap = lambda step : np.array(cmap(step)[0:3])
    old_LUT = np.array(list(map(reduced_cmap, step_list)))
    new_LUT = np.array(list(map(function, old_LUT)))
    # Now try to make a minimal segment definition of the new LUT
    cdict = {}
    for i, key in enumerate(['red','green','blue']):
        this_cdict = {}
        for j, step in enumerate(step_list):
            if step in step_dict[key]:
                this_cdict[step] = new_LUT[j, i]
            elif new_LUT[j,i] != old_LUT[j, i]:
                this_cdict[step] = new_LUT[j, i]
        colorvector = list(map(lambda x: x + (x[1], ), this_cdict.items()))
        colorvector.sort()
        cdict[key] = colorvector

    return matplotlib.colors.LinearSegmentedColormap('colormap',cdict,1024)

# %%
light_cmap = cmap_map(lambda x: x/2 + 0.5, matplotlib.cm.YlGnBu)

# %%
df_type = {
    'ARI': 'Bio conservation',
    'NMI': 'Bio conservation',
    'Label ASW': 'Bio conservation',
    'Isolated label ASW': 'Bio conservation',
    'Batch ASW': 'Batch correction',
    'Graph Connectivity': 'Batch correction',
    'Bio conservation': 'Aggregate score',
    'Batch correction': 'Aggregate score',
    'Total': 'Aggregate score',
}
df_type = pd.DataFrame(df_type, index=['Metric Type'])
df_type
# Out:
#                           ARI               NMI         Label ASW  \
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW         Batch ASW Graph Connectivity  \
# Metric Type   Bio conservation  Batch correction   Batch correction
#
#             Bio conservation Batch correction            Total
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %% [markdown]
# # Hao

# %%
df_mofa = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/MOFA+/hao_mofa.csv', index_col=0, header=0)
df_mofa = df_mofa.dropna()
df_mofa = df_mofa.T
df_mofa = df_mofa.rename(index={'0': 'MOFA+'})
df_mofa
# Out:
#        NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MOFA+           0.768382           0.598376    0.58269         0.774562
#
#        isolated_label_silhouette  graph_conn
# MOFA+                   0.536573    0.921138

# %%
df_multigrate = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/metrics/metrics_multigrate_hao.csv', index_col=0, header=0)
df_multigrate = df_multigrate.dropna()
df_multigrate = df_multigrate.T
df_multigrate = df_multigrate.rename(index={'0': 'Multigrate'})
df_multigrate
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate           0.836174           0.798786   0.654312         0.891315
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.545461    0.950743

# %%
# df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/multivi-totalvi/hao_totalvi.csv', index_col=0, header=0)
df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/code/recomb_multimodal_q2r/data/hao/0.001_embed.csv', index_col=0, header=0)
df_totalvi = df_totalvi.dropna()
df_totalvi = df_totalvi.T
df_totalvi = df_totalvi.rename(index={'0': 'totalVI'})
df_totalvi
# Out:
#          NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# totalVI           0.818238           0.679629   0.577603          0.93607
#
#          isolated_label_silhouette  graph_conn
# totalVI                   0.598906      0.9814

# %%
df_wnn = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/metrics/metrics_wnn_hao.csv', index_col=0, header=0)
df_wnn = df_wnn.dropna()
df_wnn = df_wnn.T
df_wnn = df_wnn.rename(index={'0': 'Seurat WNN'})
df_wnn
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Seurat WNN           0.841681           0.710358   0.571911         0.877684
#
#             isolated_label_silhouette  graph_conn
# Seurat WNN                   0.560389     0.98399

# %%
df = pd.concat([df_multigrate, df_mofa, df_totalvi, df_wnn])
df
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate           0.836174           0.798786   0.654312         0.891315
# MOFA+                0.768382           0.598376   0.582690         0.774562
# totalVI              0.818238           0.679629   0.577603         0.936070
# Seurat WNN           0.841681           0.710358   0.571911         0.877684
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.545461    0.950743
# MOFA+                        0.536573    0.921138
# totalVI                      0.598906    0.981400
# Seurat WNN                   0.560389    0.983990

# %%
df = df.rename(columns={
    'NMI_cluster/label': 'NMI', 
    'ARI_cluster/label': 'ARI',
    'ASW_label': 'Label ASW',
    'ASW_label/batch': 'Batch ASW',
    'isolated_label_silhouette': 'Isolated label ASW',
    'graph_conn': 'Graph Connectivity',
})

# %%
df.loc[:, 'Bio conservation'] = np.mean([df.loc[:, 'ARI'], df.loc[:, 'NMI'], df.loc[:, 'Isolated label ASW'], df.loc[:, 'Label ASW']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.836174  0.798786   0.654312   0.891315            0.545461
# MOFA+       0.768382  0.598376   0.582690   0.774562            0.536573
# totalVI     0.818238  0.679629   0.577603   0.936070            0.598906
# Seurat WNN  0.841681  0.710358   0.571911   0.877684            0.560389
#
#             Graph Connectivity  Bio conservation
# Multigrate            0.950743          0.708683
# MOFA+                 0.921138          0.621505
# totalVI               0.981400          0.668594
# Seurat WNN            0.983990          0.671085

# %%
df.loc[:, 'Batch correction'] = np.mean([df.loc[:, 'Batch ASW'], df.loc[:, 'Graph Connectivity']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.836174  0.798786   0.654312   0.891315            0.545461
# MOFA+       0.768382  0.598376   0.582690   0.774562            0.536573
# totalVI     0.818238  0.679629   0.577603   0.936070            0.598906
# Seurat WNN  0.841681  0.710358   0.571911   0.877684            0.560389
#
#             Graph Connectivity  Bio conservation  Batch correction
# Multigrate            0.950743          0.708683          0.921029
# MOFA+                 0.921138          0.621505          0.847850
# totalVI               0.981400          0.668594          0.958735
# Seurat WNN            0.983990          0.671085          0.930837

# %%
df.loc[:, 'Total'] = 0.6 * df.loc[:, 'Bio conservation'] + 0.4 * df.loc[:, 'Batch correction']

# %%
df = pd.concat([df, df_type])

# %%
score_cols = df.columns[df.loc['Metric Type'] == 'Aggregate score']
other_cols = df.columns[df.loc['Metric Type'] != 'Aggregate score']

# %%
plot_df = df.drop('Metric Type', axis=0)

# %%
plot_df = plot_df.sort_values(by="Total", ascending=False).astype(np.float64)

# %%
plot_df["Method"] = plot_df.index

# %%
column_definitions = [
    ColumnDefinition("Method", width=1.5, textprops={"ha": "left", "weight": "bold"}),
]

# %%
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate           0.836174          0.798786          0.654312
# MOFA+                0.768382          0.598376           0.58269
# totalVI              0.818238          0.679629          0.577603
# Seurat WNN           0.841681          0.710358          0.571911
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#                     Batch ASW Isolated label ASW Graph Connectivity  \
# Multigrate           0.891315           0.545461           0.950743
# MOFA+                0.774562           0.536573           0.921138
# totalVI               0.93607           0.598906             0.9814
# Seurat WNN           0.877684           0.560389            0.98399
# Metric Type  Batch correction   Bio conservation   Batch correction
#
#             Bio conservation Batch correction            Total
# Multigrate          0.708683         0.921029         0.793622
# MOFA+               0.621505          0.84785         0.712043
# totalVI             0.668594         0.958735          0.78465
# Seurat WNN          0.671085         0.930837         0.774986
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
df = df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total']]
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate           0.836174          0.798786          0.654312
# MOFA+                0.768382          0.598376           0.58269
# totalVI              0.818238          0.679629          0.577603
# Seurat WNN           0.841681          0.710358          0.571911
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW         Batch ASW Graph Connectivity  \
# Multigrate            0.545461          0.891315           0.950743
# MOFA+                 0.536573          0.774562           0.921138
# totalVI               0.598906           0.93607             0.9814
# Seurat WNN            0.560389          0.877684            0.98399
# Metric Type   Bio conservation  Batch correction   Batch correction
#
#             Bio conservation Batch correction            Total
# Multigrate          0.708683         0.921029         0.793622
# MOFA+               0.621505          0.84785         0.712043
# totalVI             0.668594         0.958735          0.78465
# Seurat WNN          0.671085         0.930837         0.774986
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
plot_df = plot_df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total', 'Method']]
plot_df
# Out:
#                  NMI       ARI  Label ASW  Isolated label ASW  Batch ASW  \
# Multigrate  0.836174  0.798786   0.654312            0.545461   0.891315
# totalVI     0.818238  0.679629   0.577603            0.598906   0.936070
# Seurat WNN  0.841681  0.710358   0.571911            0.560389   0.877684
# MOFA+       0.768382  0.598376   0.582690            0.536573   0.774562
#
#             Graph Connectivity  Bio conservation  Batch correction     Total  \
# Multigrate            0.950743          0.708683          0.921029  0.793622
# totalVI               0.981400          0.668594          0.958735  0.784650
# Seurat WNN            0.983990          0.671085          0.930837  0.774986
# MOFA+                 0.921138          0.621505          0.847850  0.712043
#
#                 Method
# Multigrate  Multigrate
# totalVI        totalVI
# Seurat WNN  Seurat WNN
# MOFA+            MOFA+

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=matplotlib.cm.PRGn, num_stds=2.5)

# Circles for the metric values
column_definitions += [
    ColumnDefinition(
        col,
        title=col.replace(" ", "\n", 1),
        width=1,
        textprops={
            "ha": "center",
            "bbox": {"boxstyle": "circle", "pad": 0.25},
        },
        cmap=cmap_fn(plot_df[col]),
        group=df.loc['Metric Type', col],
        formatter="{:.2f}",
    )
    for i, col in enumerate(other_cols)
]

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=light_cmap, num_stds=2.5)

# Bars for the aggregate scores
column_definitions += [
    ColumnDefinition(
        col,
        width=1,
        title=col.replace(" ", "\n", 1),
        plot_fn=bar,
        plot_kw={
            "cmap": cmap_fn(plot_df[col]),
            "plot_bg_bar": False,
            "annotate": True,
            "height": 0.9,
            "formatter": "{:.2f}",
        },
        group=df.loc['Metric Type', col],
        border="left" if i == 0 else None,
    )
    for i, col in enumerate(score_cols)
]

# %%
num_embeds = len(plot_df)

# Allow to manipulate text post-hoc (in illustrator)
with matplotlib.rc_context({"svg.fonttype": "none"}):
    fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
    tab = Table(
        plot_df,
        cell_kw={
            "linewidth": 0,
            "edgecolor": "k",
        },
        column_definitions=column_definitions,
        ax=ax,
        row_dividers=True,
        footer_divider=True,
        textprops={"fontsize": 9, "ha": "center"},
        row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
        col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
        column_border_kw={"linewidth": 1, "linestyle": "-"},
        index_col="Method",
    ).autoset_fontcolors(colnames=plot_df.columns)

plt.savefig('figures/scib_table_hao.svg', bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 23
#       5     fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
#       6     tab = Table(
#       7         plot_df,
#       8         cell_kw={
#    (...)
#      20         index_col="Method",
#      21     ).autoset_fontcolors(colnames=plot_df.columns)
# ---> 23 plt.savefig('figures/scib_table_hao.svg', bbox_inches='tight')
#      25 plt.show()
#
# File /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/sc/lib/python3.10/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/sc/lib/python3.10/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
#    3376             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3378 self.canvas.print_figure(fname, **kwargs)
#
# File /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/sc/lib/python3.10/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/sc/lib/python3.10/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/sc/lib/python3.10/site-packages/matplotlib/backends/backend_svg.py:1358, in FigureCanvasSVG.print_svg(self, filename, bbox_inches_restore, metadata)
#    1326 def print_svg(self, filename, *, bbox_inches_restore=None, metadata=None):
#    1327     """
#    1328     Parameters
#    1329     ----------
#    (...)
#    1356         __ DC_
#    1357     """
# -> 1358     with cbook.open_file_cm(filename, "w", encoding="utf-8") as fh:
#    1359         if not cbook.file_requires_unicode(fh):
#    1360             fh = codecs.getwriter('utf-8')(fh)
#
# File /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/sc/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:508, in open_file_cm(path_or_file, mode, encoding)
#     506 def open_file_cm(path_or_file, mode="r", encoding=None):
#     507     r"""Pass through file objects and context-manage path-likes."""
# --> 508     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     509     return fh if opened else contextlib.nullcontext(fh)
#
# File /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/sc/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:494, in to_filehandle(fname, flag, return_opened, encoding)
#     492         fh = bz2.BZ2File(fname, flag)
#     493     else:
# --> 494         fh = open(fname, flag, encoding=encoding)
#     495     opened = True
#     496 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/scib_table_hao.svg'

# %% [markdown]
# # neurips cite

# %%
df_mofa = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/MOFA+/neurips_cite_mofa.csv', index_col=0, header=0)
df_mofa = df_mofa.dropna()
df_mofa = df_mofa.T
df_mofa = df_mofa.rename(index={'0': 'MOFA+'})
df_mofa
# Out:
#        NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MOFA+           0.640398           0.374594   0.570123         0.804016
#
#        isolated_label_silhouette  graph_conn
# MOFA+                   0.445597    0.844645

# %%
df_multigrate = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/metrics/metrics_multigrate_neurips_cite.csv', index_col=0, header=0)
df_multigrate = df_multigrate.dropna()
df_multigrate = df_multigrate.T
df_multigrate = df_multigrate.rename(index={'0': 'MultiMIL'})
df_multigrate
# Out:
#           NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MultiMIL            0.79275            0.74074   0.607309         0.818657
#
#           isolated_label_silhouette  graph_conn
# MultiMIL                   0.491202    0.909775

# %%
df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/multivi-totalvi/neurips_cite_totalvi.csv', index_col=0, header=0)
df_totalvi = df_totalvi.dropna()
df_totalvi = df_totalvi.T
df_totalvi = df_totalvi.rename(index={'0': 'totalVI'})
df_totalvi
# Out:
#          NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# totalVI           0.795523           0.770435   0.559358         0.894195
#
#          isolated_label_silhouette  graph_conn
# totalVI                   0.569714    0.933765

# %%
df_wnn = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/metrics/metrics_wnn_neurips_cite.csv', index_col=0, header=0)
df_wnn = df_wnn.dropna()
df_wnn = df_wnn.T
df_wnn = df_wnn.rename(index={'0': 'Seurat WNN'})
df_wnn
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Seurat WNN           0.759189           0.655493   0.573505         0.798508
#
#             isolated_label_silhouette  graph_conn
# Seurat WNN                   0.508281    0.915899

# %%
df = pd.concat([df_multigrate, df_mofa, df_totalvi, df_wnn])
df
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MultiMIL             0.792750           0.740740   0.607309         0.818657
# MOFA+                0.640398           0.374594   0.570123         0.804016
# totalVI              0.795523           0.770435   0.559358         0.894195
# Seurat WNN           0.759189           0.655493   0.573505         0.798508
#
#             isolated_label_silhouette  graph_conn
# MultiMIL                     0.491202    0.909775
# MOFA+                        0.445597    0.844645
# totalVI                      0.569714    0.933765
# Seurat WNN                   0.508281    0.915899

# %%
df = df.rename(columns={
    'NMI_cluster/label': 'NMI', 
    'ARI_cluster/label': 'ARI',
    'ASW_label': 'Label ASW',
    'ASW_label/batch': 'Batch ASW',
    'isolated_label_silhouette': 'Isolated label ASW',
    'graph_conn': 'Graph Connectivity',
})

# %%
df.loc[:, 'Bio conservation'] = np.mean([df.loc[:, 'ARI'], df.loc[:, 'NMI'], df.loc[:, 'Isolated label ASW'], df.loc[:, 'Label ASW']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# MultiMIL    0.792750  0.740740   0.607309   0.818657            0.491202
# MOFA+       0.640398  0.374594   0.570123   0.804016            0.445597
# totalVI     0.795523  0.770435   0.559358   0.894195            0.569714
# Seurat WNN  0.759189  0.655493   0.573505   0.798508            0.508281
#
#             Graph Connectivity  Bio conservation
# MultiMIL              0.909775          0.658000
# MOFA+                 0.844645          0.507678
# totalVI               0.933765          0.673757
# Seurat WNN            0.915899          0.624117

# %%
df.loc[:, 'Batch correction'] = np.mean([df.loc[:, 'Batch ASW'], df.loc[:, 'Graph Connectivity']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# MultiMIL    0.792750  0.740740   0.607309   0.818657            0.491202
# MOFA+       0.640398  0.374594   0.570123   0.804016            0.445597
# totalVI     0.795523  0.770435   0.559358   0.894195            0.569714
# Seurat WNN  0.759189  0.655493   0.573505   0.798508            0.508281
#
#             Graph Connectivity  Bio conservation  Batch correction
# MultiMIL              0.909775          0.658000          0.864216
# MOFA+                 0.844645          0.507678          0.824331
# totalVI               0.933765          0.673757          0.913980
# Seurat WNN            0.915899          0.624117          0.857204

# %%
df.loc[:, 'Total'] = 0.6 * df.loc[:, 'Bio conservation'] + 0.4 * df.loc[:, 'Batch correction']

# %%
df = pd.concat([df, df_type])

# %%
score_cols = df.columns[df.loc['Metric Type'] == 'Aggregate score']
other_cols = df.columns[df.loc['Metric Type'] != 'Aggregate score']

# %%
plot_df = df.drop('Metric Type', axis=0)

# %%
plot_df = plot_df.sort_values(by="Total", ascending=False).astype(np.float64)

# %%
plot_df["Method"] = plot_df.index

# %%
column_definitions = [
    ColumnDefinition("Method", width=1.5, textprops={"ha": "left", "weight": "bold"}),
]

# %%
df
# Out:
#                           NMI               ARI         Label ASW  \
# MultiMIL              0.79275           0.74074          0.607309
# MOFA+                0.640398          0.374594          0.570123
# totalVI              0.795523          0.770435          0.559358
# Seurat WNN           0.759189          0.655493          0.573505
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#                     Batch ASW Isolated label ASW Graph Connectivity  \
# MultiMIL             0.818657           0.491202           0.909775
# MOFA+                0.804016           0.445597           0.844645
# totalVI              0.894195           0.569714           0.933765
# Seurat WNN           0.798508           0.508281           0.915899
# Metric Type  Batch correction   Bio conservation   Batch correction
#
#             Bio conservation Batch correction            Total
# MultiMIL               0.658         0.864216         0.740487
# MOFA+               0.507678         0.824331         0.634339
# totalVI             0.673757          0.91398         0.769846
# Seurat WNN          0.624117         0.857204         0.717352
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
df = df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total']]
df
# Out:
#                           NMI               ARI         Label ASW  \
# MultiMIL              0.79275           0.74074          0.607309
# MOFA+                0.640398          0.374594          0.570123
# totalVI              0.795523          0.770435          0.559358
# Seurat WNN           0.759189          0.655493          0.573505
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW         Batch ASW Graph Connectivity  \
# MultiMIL              0.491202          0.818657           0.909775
# MOFA+                 0.445597          0.804016           0.844645
# totalVI               0.569714          0.894195           0.933765
# Seurat WNN            0.508281          0.798508           0.915899
# Metric Type   Bio conservation  Batch correction   Batch correction
#
#             Bio conservation Batch correction            Total
# MultiMIL               0.658         0.864216         0.740487
# MOFA+               0.507678         0.824331         0.634339
# totalVI             0.673757          0.91398         0.769846
# Seurat WNN          0.624117         0.857204         0.717352
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
plot_df = plot_df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total', 'Method']]
plot_df
# Out:
#                  NMI       ARI  Label ASW  Isolated label ASW  Batch ASW  \
# totalVI     0.795523  0.770435   0.559358            0.569714   0.894195
# MultiMIL    0.792750  0.740740   0.607309            0.491202   0.818657
# Seurat WNN  0.759189  0.655493   0.573505            0.508281   0.798508
# MOFA+       0.640398  0.374594   0.570123            0.445597   0.804016
#
#             Graph Connectivity  Bio conservation  Batch correction     Total  \
# totalVI               0.933765          0.673757          0.913980  0.769846
# MultiMIL              0.909775          0.658000          0.864216  0.740487
# Seurat WNN            0.915899          0.624117          0.857204  0.717352
# MOFA+                 0.844645          0.507678          0.824331  0.634339
#
#                 Method
# totalVI        totalVI
# MultiMIL      MultiMIL
# Seurat WNN  Seurat WNN
# MOFA+            MOFA+

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=matplotlib.cm.PRGn, num_stds=2.5)

# Circles for the metric values
column_definitions += [
    ColumnDefinition(
        col,
        title=col.replace(" ", "\n", 1),
        width=1,
        textprops={
            "ha": "center",
            "bbox": {"boxstyle": "circle", "pad": 0.25},
        },
        cmap=cmap_fn(plot_df[col]),
        group=df.loc['Metric Type', col],
        formatter="{:.2f}",
    )
    for i, col in enumerate(other_cols)
]

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=light_cmap, num_stds=2.5)

# Bars for the aggregate scores
column_definitions += [
    ColumnDefinition(
        col,
        width=1,
        title=col.replace(" ", "\n", 1),
        plot_fn=bar,
        plot_kw={
            "cmap": cmap_fn(plot_df[col]),
            "plot_bg_bar": False,
            "annotate": True,
            "height": 0.9,
            "formatter": "{:.2f}",
        },
        group=df.loc['Metric Type', col],
        border="left" if i == 0 else None,
    )
    for i, col in enumerate(score_cols)
]

# %%
num_embeds = len(plot_df)

# Allow to manipulate text post-hoc (in illustrator)
with matplotlib.rc_context({"svg.fonttype": "none"}):
    fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
    tab = Table(
        plot_df,
        cell_kw={
            "linewidth": 0,
            "edgecolor": "k",
        },
        column_definitions=column_definitions,
        ax=ax,
        row_dividers=True,
        footer_divider=True,
        textprops={"fontsize": 9, "ha": "center"},
        row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
        col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
        column_border_kw={"linewidth": 1, "linestyle": "-"},
        index_col="Method",
    ).autoset_fontcolors(colnames=plot_df.columns)

plt.savefig('figures/scib_table_neurips_cite.svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# # neurips multiome

# %%
df_mofa = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/MOFA+/neurips_multiome_mofa.csv', index_col=0, header=0)
df_mofa = df_mofa.dropna()
df_mofa = df_mofa.T
df_mofa = df_mofa.rename(index={'0': 'MOFA+'})
df_mofa
# Out:
#        NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MOFA+           0.606385           0.258605   0.534082         0.813457
#
#        isolated_label_silhouette  graph_conn
# MOFA+                   0.486203    0.923153

# %%
df_multigrate = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/metrics/metrics_multigrate_neurips_multiome.csv', index_col=0, header=0)
df_multigrate = df_multigrate.dropna()
df_multigrate = df_multigrate.T
df_multigrate = df_multigrate.rename(index={'0': 'MultiMIL'})
df_multigrate
# Out:
#           NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MultiMIL           0.759771           0.658101   0.603824         0.835437
#
#           isolated_label_silhouette  graph_conn
# MultiMIL                   0.532891    0.952599

# %%
df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/multivi-totalvi/neurips_multiome_multivi.csv', index_col=0, header=0)
df_totalvi = df_totalvi.dropna()
df_totalvi = df_totalvi.T
df_totalvi = df_totalvi.rename(index={'0': 'multiVI'})
df_totalvi
# Out:
#          NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# multiVI           0.750965           0.657998   0.586747         0.817665
#
#          isolated_label_silhouette  graph_conn
# multiVI                   0.510359    0.949493

# %%
df_wnn = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/metrics/metrics_wnn_neurips_multiome.csv', index_col=0, header=0)
df_wnn = df_wnn.dropna()
df_wnn = df_wnn.T
df_wnn = df_wnn.rename(index={'0': 'Seurat WNN'})
df_wnn
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Seurat WNN            0.77005           0.670767   0.590048         0.805851
#
#             isolated_label_silhouette  graph_conn
# Seurat WNN                   0.394926    0.970181

# %%
df = pd.concat([df_multigrate, df_mofa, df_totalvi, df_wnn])
df
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MultiMIL             0.759771           0.658101   0.603824         0.835437
# MOFA+                0.606385           0.258605   0.534082         0.813457
# multiVI              0.750965           0.657998   0.586747         0.817665
# Seurat WNN           0.770050           0.670767   0.590048         0.805851
#
#             isolated_label_silhouette  graph_conn
# MultiMIL                     0.532891    0.952599
# MOFA+                        0.486203    0.923153
# multiVI                      0.510359    0.949493
# Seurat WNN                   0.394926    0.970181

# %%
df = df.rename(columns={
    'NMI_cluster/label': 'NMI', 
    'ARI_cluster/label': 'ARI',
    'ASW_label': 'Label ASW',
    'ASW_label/batch': 'Batch ASW',
    'isolated_label_silhouette': 'Isolated label ASW',
    'graph_conn': 'Graph Connectivity',
})

# %%
df.loc[:, 'Bio conservation'] = np.mean([df.loc[:, 'ARI'], df.loc[:, 'NMI'], df.loc[:, 'Isolated label ASW'], df.loc[:, 'Label ASW']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# MultiMIL    0.759771  0.658101   0.603824   0.835437            0.532891
# MOFA+       0.606385  0.258605   0.534082   0.813457            0.486203
# multiVI     0.750965  0.657998   0.586747   0.817665            0.510359
# Seurat WNN  0.770050  0.670767   0.590048   0.805851            0.394926
#
#             Graph Connectivity  Bio conservation
# MultiMIL              0.952599          0.638647
# MOFA+                 0.923153          0.471319
# multiVI               0.949493          0.626517
# Seurat WNN            0.970181          0.606448

# %%
df.loc[:, 'Batch correction'] = np.mean([df.loc[:, 'Batch ASW'], df.loc[:, 'Graph Connectivity']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# MultiMIL    0.759771  0.658101   0.603824   0.835437            0.532891
# MOFA+       0.606385  0.258605   0.534082   0.813457            0.486203
# multiVI     0.750965  0.657998   0.586747   0.817665            0.510359
# Seurat WNN  0.770050  0.670767   0.590048   0.805851            0.394926
#
#             Graph Connectivity  Bio conservation  Batch correction
# MultiMIL              0.952599          0.638647          0.894018
# MOFA+                 0.923153          0.471319          0.868305
# multiVI               0.949493          0.626517          0.883579
# Seurat WNN            0.970181          0.606448          0.888016

# %%
df.loc[:, 'Total'] = 0.6 * df.loc[:, 'Bio conservation'] + 0.4 * df.loc[:, 'Batch correction']

# %%
df = pd.concat([df, df_type])

# %%
score_cols = df.columns[df.loc['Metric Type'] == 'Aggregate score']
other_cols = df.columns[df.loc['Metric Type'] != 'Aggregate score']

# %%
plot_df = df.drop('Metric Type', axis=0)

# %%
plot_df = plot_df.sort_values(by="Total", ascending=False).astype(np.float64)

# %%
plot_df["Method"] = plot_df.index

# %%
column_definitions = [
    ColumnDefinition("Method", width=1.5, textprops={"ha": "left", "weight": "bold"}),
]

# %%
df
# Out:
#                           NMI               ARI         Label ASW  \
# MultiMIL             0.759771          0.658101          0.603824
# MOFA+                0.606385          0.258605          0.534082
# multiVI              0.750965          0.657998          0.586747
# Seurat WNN            0.77005          0.670767          0.590048
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#                     Batch ASW Isolated label ASW Graph Connectivity  \
# MultiMIL             0.835437           0.532891           0.952599
# MOFA+                0.813457           0.486203           0.923153
# multiVI              0.817665           0.510359           0.949493
# Seurat WNN           0.805851           0.394926           0.970181
# Metric Type  Batch correction   Bio conservation   Batch correction
#
#             Bio conservation Batch correction            Total
# MultiMIL            0.638647         0.894018         0.740795
# MOFA+               0.471319         0.868305         0.630113
# multiVI             0.626517         0.883579         0.729342
# Seurat WNN          0.606448         0.888016         0.719075
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
df = df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total']]
df
# Out:
#                           NMI               ARI         Label ASW  \
# MultiMIL             0.759771          0.658101          0.603824
# MOFA+                0.606385          0.258605          0.534082
# multiVI              0.750965          0.657998          0.586747
# Seurat WNN            0.77005          0.670767          0.590048
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW         Batch ASW Graph Connectivity  \
# MultiMIL              0.532891          0.835437           0.952599
# MOFA+                 0.486203          0.813457           0.923153
# multiVI               0.510359          0.817665           0.949493
# Seurat WNN            0.394926          0.805851           0.970181
# Metric Type   Bio conservation  Batch correction   Batch correction
#
#             Bio conservation Batch correction            Total
# MultiMIL            0.638647         0.894018         0.740795
# MOFA+               0.471319         0.868305         0.630113
# multiVI             0.626517         0.883579         0.729342
# Seurat WNN          0.606448         0.888016         0.719075
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
plot_df = plot_df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total', 'Method']]
plot_df
# Out:
#                  NMI       ARI  Label ASW  Isolated label ASW  Batch ASW  \
# MultiMIL    0.759771  0.658101   0.603824            0.532891   0.835437
# multiVI     0.750965  0.657998   0.586747            0.510359   0.817665
# Seurat WNN  0.770050  0.670767   0.590048            0.394926   0.805851
# MOFA+       0.606385  0.258605   0.534082            0.486203   0.813457
#
#             Graph Connectivity  Bio conservation  Batch correction     Total  \
# MultiMIL              0.952599          0.638647          0.894018  0.740795
# multiVI               0.949493          0.626517          0.883579  0.729342
# Seurat WNN            0.970181          0.606448          0.888016  0.719075
# MOFA+                 0.923153          0.471319          0.868305  0.630113
#
#                 Method
# MultiMIL      MultiMIL
# multiVI        multiVI
# Seurat WNN  Seurat WNN
# MOFA+            MOFA+

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=matplotlib.cm.PRGn, num_stds=2.5)

# Circles for the metric values
column_definitions += [
    ColumnDefinition(
        col,
        title=col.replace(" ", "\n", 1),
        width=1,
        textprops={
            "ha": "center",
            "bbox": {"boxstyle": "circle", "pad": 0.25},
        },
        cmap=cmap_fn(plot_df[col]),
        group=df.loc['Metric Type', col],
        formatter="{:.2f}",
    )
    for i, col in enumerate(other_cols)
]

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=light_cmap, num_stds=2.5)

# Bars for the aggregate scores
column_definitions += [
    ColumnDefinition(
        col,
        width=1,
        title=col.replace(" ", "\n", 1),
        plot_fn=bar,
        plot_kw={
            "cmap": cmap_fn(plot_df[col]),
            "plot_bg_bar": False,
            "annotate": True,
            "height": 0.9,
            "formatter": "{:.2f}",
        },
        group=df.loc['Metric Type', col],
        border="left" if i == 0 else None,
    )
    for i, col in enumerate(score_cols)
]

# %%
num_embeds = len(plot_df)

# Allow to manipulate text post-hoc (in illustrator)
with matplotlib.rc_context({"svg.fonttype": "none"}):
    fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
    tab = Table(
        plot_df,
        cell_kw={
            "linewidth": 0,
            "edgecolor": "k",
        },
        column_definitions=column_definitions,
        ax=ax,
        row_dividers=True,
        footer_divider=True,
        textprops={"fontsize": 9, "ha": "center"},
        row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
        col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
        column_border_kw={"linewidth": 1, "linestyle": "-"},
        index_col="Method",
    ).autoset_fontcolors(colnames=plot_df.columns)

plt.savefig('figures/scib_table_neurips_multiome.svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# # 10x

# %%
df_mofa = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/MOFA+/10x_mofa.csv', index_col=0, header=0)
df_mofa = df_mofa.dropna()
df_mofa = df_mofa.T
df_mofa = df_mofa.rename(index={'0': 'MOFA+'})
df_mofa
# Out:
#        NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MOFA+           0.791609           0.718718   0.632117         0.953821
#
#        isolated_label_silhouette  graph_conn
# MOFA+                   0.578131    0.992759

# %%
df_multigrate = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/metrics/metrics_multigrate_10x.csv', index_col=0, header=0)
df_multigrate = df_multigrate.dropna()
df_multigrate = df_multigrate.T
df_multigrate = df_multigrate.rename(index={'0': 'MultiMIL'})
df_multigrate
# Out:
#           NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MultiMIL            0.79917           0.744534   0.674276         0.950534
#
#           isolated_label_silhouette  graph_conn
# MultiMIL                   0.552052    0.987826

# %%
df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/multivi-totalvi/10x_multivi.csv', index_col=0, header=0)
df_totalvi = df_totalvi.dropna()
df_totalvi = df_totalvi.T
df_totalvi = df_totalvi.rename(index={'0': 'multiVI'})
df_totalvi
# Out:
#          NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# multiVI           0.775666           0.633357   0.594879         0.976125
#
#          isolated_label_silhouette  graph_conn
# multiVI                   0.551268    0.969992

# %%
df_wnn = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/metrics/metrics_wnn_10x.csv', index_col=0, header=0)
df_wnn = df_wnn.dropna()
df_wnn = df_wnn.T
df_wnn = df_wnn.rename(index={'0': 'Seurat WNN'})
df_wnn
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Seurat WNN            0.81687           0.749073   0.605977          0.96876
#
#             isolated_label_silhouette  graph_conn
# Seurat WNN                   0.579861    0.974883

# %%
df = pd.concat([df_multigrate, df_mofa, df_totalvi, df_wnn])
df
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MultiMIL             0.799170           0.744534   0.674276         0.950534
# MOFA+                0.791609           0.718718   0.632117         0.953821
# multiVI              0.775666           0.633357   0.594879         0.976125
# Seurat WNN           0.816870           0.749073   0.605977         0.968760
#
#             isolated_label_silhouette  graph_conn
# MultiMIL                     0.552052    0.987826
# MOFA+                        0.578131    0.992759
# multiVI                      0.551268    0.969992
# Seurat WNN                   0.579861    0.974883

# %%
df = df.rename(columns={
    'NMI_cluster/label': 'NMI', 
    'ARI_cluster/label': 'ARI',
    'ASW_label': 'Label ASW',
    'ASW_label/batch': 'Batch ASW',
    'isolated_label_silhouette': 'Isolated label ASW',
    'graph_conn': 'Graph Connectivity',
})

# %%
df.loc[:, 'Bio conservation'] = np.mean([df.loc[:, 'ARI'], df.loc[:, 'NMI'], df.loc[:, 'Isolated label ASW'], df.loc[:, 'Label ASW']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# MultiMIL    0.799170  0.744534   0.674276   0.950534            0.552052
# MOFA+       0.791609  0.718718   0.632117   0.953821            0.578131
# multiVI     0.775666  0.633357   0.594879   0.976125            0.551268
# Seurat WNN  0.816870  0.749073   0.605977   0.968760            0.579861
#
#             Graph Connectivity  Bio conservation
# MultiMIL              0.987826          0.692508
# MOFA+                 0.992759          0.680144
# multiVI               0.969992          0.638792
# Seurat WNN            0.974883          0.687945

# %%
df.loc[:, 'Total'] = df.loc[:, 'Bio conservation']

# %%
df = pd.concat([df, df_type])

# %%
df = df.drop(['Graph Connectivity', 'Batch correction', 'Batch ASW'], axis=1)
df
# Out:
#                           NMI               ARI         Label ASW  \
# MultiMIL              0.79917          0.744534          0.674276
# MOFA+                0.791609          0.718718          0.632117
# multiVI              0.775666          0.633357          0.594879
# Seurat WNN            0.81687          0.749073          0.605977
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW Bio conservation            Total
# MultiMIL              0.552052         0.692508         0.692508
# MOFA+                 0.578131         0.680144         0.680144
# multiVI               0.551268         0.638792         0.638792
# Seurat WNN            0.579861         0.687945         0.687945
# Metric Type   Bio conservation  Aggregate score  Aggregate score

# %%
score_cols = df.columns[df.loc['Metric Type'] == 'Aggregate score']
other_cols = df.columns[df.loc['Metric Type'] != 'Aggregate score']

# %%
plot_df = df.drop('Metric Type', axis=0)

# %%
plot_df = plot_df.sort_values(by="Total", ascending=False).astype(np.float64)

# %%
plot_df["Method"] = plot_df.index

# %%
column_definitions = [
    ColumnDefinition("Method", width=1.5, textprops={"ha": "left", "weight": "bold"}),
]

# %%
df
# Out:
#                           NMI               ARI         Label ASW  \
# MultiMIL              0.79917          0.744534          0.674276
# MOFA+                0.791609          0.718718          0.632117
# multiVI              0.775666          0.633357          0.594879
# Seurat WNN            0.81687          0.749073          0.605977
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW Bio conservation            Total
# MultiMIL              0.552052         0.692508         0.692508
# MOFA+                 0.578131         0.680144         0.680144
# multiVI               0.551268         0.638792         0.638792
# Seurat WNN            0.579861         0.687945         0.687945
# Metric Type   Bio conservation  Aggregate score  Aggregate score

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=matplotlib.cm.PRGn, num_stds=2.5)

# Circles for the metric values
column_definitions += [
    ColumnDefinition(
        col,
        title=col.replace(" ", "\n", 1),
        width=1,
        textprops={
            "ha": "center",
            "bbox": {"boxstyle": "circle", "pad": 0.25},
        },
        cmap=cmap_fn(plot_df[col]),
        group=df.loc['Metric Type', col],
        formatter="{:.2f}",
    )
    for i, col in enumerate(other_cols)
]

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=light_cmap, num_stds=2.5)

# Bars for the aggregate scores
column_definitions += [
    ColumnDefinition(
        col,
        width=1,
        title=col.replace(" ", "\n", 1),
        plot_fn=bar,
        plot_kw={
            "cmap": cmap_fn(plot_df[col]),
            "plot_bg_bar": False,
            "annotate": True,
            "height": 0.9,
            "formatter": "{:.2f}",
        },
        group=df.loc['Metric Type', col],
        border="left" if i == 0 else None,
    )
    for i, col in enumerate(score_cols)
]

# %%
num_embeds = len(plot_df)

# Allow to manipulate text post-hoc (in illustrator)
with matplotlib.rc_context({"svg.fonttype": "none"}):
    fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
    tab = Table(
        plot_df,
        cell_kw={
            "linewidth": 0,
            "edgecolor": "k",
        },
        column_definitions=column_definitions,
        ax=ax,
        row_dividers=True,
        footer_divider=True,
        textprops={"fontsize": 9, "ha": "center"},
        row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
        col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
        column_border_kw={"linewidth": 1, "linestyle": "-"},
        index_col="Method",
    ).autoset_fontcolors(colnames=plot_df.columns)

plt.savefig('figures/scib_table_10x.svg', bbox_inches='tight')

plt.show()
