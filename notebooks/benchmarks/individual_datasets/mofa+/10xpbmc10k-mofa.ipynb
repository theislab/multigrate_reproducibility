# %%
import numpy as np
import scanpy as sc
import h5py
from mofapy2.run.entry_point import entry_point

# %% [markdown]
# # MOFA 2

# %% [markdown]
# ## Load the datasets

# %%
#todo
gdown.download(
    'https://drive.google.com/uc?id=1i5Yj7Hh6ZYn9MpJ5hikOqA-SvnYK4zvQ',
    '10xpbmc10k2020-expressions.h5ad'
)

# %%
scrna = sc.read('../data/10xpbmc10k-2020/expressions.h5ad')
scrna
# Out:
# AnnData object with n_obs × n_vars = 10000 × 4000
#     obs: 'cell_type'
#     layers: 'count'

# %%
#todo

# %%
scatac = sc.read('../data/10xpbmc10k-2020/peaks.h5ad')
scatac
# Out:
# AnnData object with n_obs × n_vars = 10000 × 40086
#     obs: 'cell_type'
#     layers: 'binary'

# %% [markdown]
# ## Configure and train the model

# %%
ent = entry_point()
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################

# %%
ent.set_data_options(
    scale_groups = False, 
    scale_views = False
)

# %%
ent.set_data_matrix([[scrna.X.A], [scatac.X.A]], views_names=['scRNA', 'scATAC'])
# Out:
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='scRNA' group='group0' with N=10000 samples and D=4000 features...
# Successfully loaded view='scATAC' group='group0' with N=10000 samples and D=40086 features...

# %%
ent.set_model_options(
    factors = 20, 
    spikeslab_weights = True, 
    ard_factors = True,
    ard_weights = True
)
# Out:
# Model options:
# - Automatic Relevance Determination prior on the factors: True
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (scRNA): gaussian
# - View 1 (scATAC): gaussian

# %%
ent.set_train_options(
    iter = 1000, 
    convergence_mode = "fast", 
    startELBO = 1, 
    freqELBO = 1, 
    dropR2 = 0.001, 
    gpu_mode = False, 
    verbose = False, 
    seed = 1
)

# %%
ent.build()

# %%
ent.run()
# Out:
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -533850218.28
#
# Iteration 1: time=672.13, ELBO=-49477990.65, deltaELBO=484372227.623 (90.73185906%), Factors=19
# Iteration 2: time=644.57, ELBO=-44371611.02, deltaELBO=5106379.638 (0.95651916%), Factors=18
# Iteration 3: time=610.36, ELBO=-43409403.10, deltaELBO=962207.917 (0.18023930%), Factors=17
# Iteration 4: time=576.94, ELBO=-43123431.40, deltaELBO=285971.703 (0.05356778%), Factors=16
# Iteration 5: time=546.21, ELBO=-42911821.08, deltaELBO=211610.312 (0.03963852%), Factors=15
# Iteration 6: time=514.08, ELBO=-42748260.83, deltaELBO=163560.253 (0.03063785%), Factors=14
# Iteration 7: time=479.70, ELBO=-42631894.62, deltaELBO=116366.212 (0.02179754%), Factors=13
# Iteration 8: time=469.61, ELBO=-42583589.56, deltaELBO=48305.058 (0.00904843%), Factors=13
# Iteration 9: time=469.84, ELBO=-42547079.32, deltaELBO=36510.238 (0.00683904%), Factors=13
# Iteration 10: time=470.84, ELBO=-42514182.09, deltaELBO=32897.227 (0.00616226%), Factors=13
# Iteration 11: time=470.62, ELBO=-42482198.92, deltaELBO=31983.172 (0.00599104%), Factors=13
# Iteration 12: time=466.74, ELBO=-42451101.84, deltaELBO=31097.087 (0.00582506%), Factors=13
# Iteration 13: time=470.71, ELBO=-42421842.04, deltaELBO=29259.792 (0.00548090%), Factors=13
# Iteration 14: time=472.95, ELBO=-42394987.13, deltaELBO=26854.918 (0.00503042%), Factors=13
# Iteration 15: time=468.00, ELBO=-42369993.36, deltaELBO=24993.767 (0.00468179%), Factors=13
# Iteration 16: time=470.95, ELBO=-42346230.99, deltaELBO=23762.368 (0.00445113%), Factors=13
# Iteration 17: time=469.98, ELBO=-42323568.87, deltaELBO=22662.117 (0.00424503%), Factors=13
# Iteration 18: time=471.78, ELBO=-42302199.66, deltaELBO=21369.211 (0.00400285%), Factors=13
# Iteration 19: time=470.26, ELBO=-42282662.37, deltaELBO=19537.296 (0.00365970%), Factors=13
# Iteration 20: time=470.19, ELBO=-42265767.13, deltaELBO=16895.236 (0.00316479%), Factors=13
# Iteration 21: time=470.39, ELBO=-42251645.48, deltaELBO=14121.649 (0.00264525%), Factors=13
# Iteration 22: time=471.96, ELBO=-42239535.55, deltaELBO=12109.932 (0.00226841%), Factors=13
# Iteration 23: time=469.52, ELBO=-42228483.17, deltaELBO=11052.378 (0.00207031%), Factors=13
# Iteration 24: time=471.13, ELBO=-42217788.28, deltaELBO=10694.891 (0.00200335%), Factors=13
# Iteration 25: time=471.05, ELBO=-42207058.05, deltaELBO=10730.230 (0.00200997%), Factors=13
# Iteration 26: time=468.39, ELBO=-42196062.46, deltaELBO=10995.588 (0.00205968%), Factors=13
# Iteration 27: time=471.01, ELBO=-42184652.00, deltaELBO=11410.466 (0.00213739%), Factors=13
# Iteration 28: time=470.86, ELBO=-42172785.10, deltaELBO=11866.900 (0.00222289%), Factors=13
# Iteration 29: time=469.71, ELBO=-42160528.25, deltaELBO=12256.845 (0.00229593%), Factors=13
# Iteration 30: time=469.13, ELBO=-42148063.61, deltaELBO=12464.645 (0.00233486%), Factors=13
# Iteration 31: time=472.42, ELBO=-42135683.79, deltaELBO=12379.819 (0.00231897%), Factors=13
# Iteration 32: time=472.55, ELBO=-42123697.78, deltaELBO=11986.011 (0.00224520%), Factors=13
# Iteration 33: time=470.89, ELBO=-42112159.98, deltaELBO=11537.797 (0.00216124%), Factors=13
# Iteration 34: time=471.35, ELBO=-42100865.70, deltaELBO=11294.285 (0.00211563%), Factors=13
# Iteration 35: time=471.50, ELBO=-42089578.39, deltaELBO=11287.303 (0.00211432%), Factors=13
# Iteration 36: time=472.12, ELBO=-42078206.48, deltaELBO=11371.912 (0.00213017%), Factors=13
# Iteration 37: time=470.37, ELBO=-42066829.48, deltaELBO=11377.003 (0.00213112%), Factors=13
# Iteration 38: time=469.49, ELBO=-42055590.44, deltaELBO=11239.036 (0.00210528%), Factors=13
# Iteration 39: time=471.74, ELBO=-42044576.40, deltaELBO=11014.049 (0.00206313%), Factors=13
# Iteration 40: time=468.36, ELBO=-42033796.26, deltaELBO=10780.139 (0.00201932%), Factors=13
# Iteration 41: time=471.74, ELBO=-42023245.12, deltaELBO=10551.139 (0.00197642%), Factors=13
# Iteration 42: time=469.84, ELBO=-42012980.58, deltaELBO=10264.537 (0.00192274%), Factors=13
# Iteration 43: time=473.01, ELBO=-42003173.84, deltaELBO=9806.737 (0.00183698%), Factors=13
# Iteration 44: time=472.89, ELBO=-41994123.85, deltaELBO=9049.997 (0.00169523%), Factors=13
# Iteration 45: time=471.10, ELBO=-41986206.96, deltaELBO=7916.884 (0.00148298%), Factors=13
# Iteration 46: time=471.62, ELBO=-41979734.65, deltaELBO=6472.317 (0.00121238%), Factors=13
# Iteration 47: time=470.59, ELBO=-41974790.89, deltaELBO=4943.760 (0.00092606%), Factors=13
# Iteration 48: time=469.32, ELBO=-41971196.35, deltaELBO=3594.538 (0.00067332%), Factors=13
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################

# %%
outfile = '10xpbmc10k-mofa2.hdf5'
ent.save(outfile)
# Out:
# Saving model in 10xpbmc10k-mofa2.hdf5...

# %% [markdown]
# ## Save results as AnnData

# %%
f = h5py.File(outfile)

# %%
z = np.concatenate([v[:,:] for k, v in f['expectations']['Z'].items()], axis=1).T
z = sc.AnnData(z)

z.obs_names = scrna.obs_names
z.obs = scrna.obs

z
# Out:
# AnnData object with n_obs × n_vars = 10000 × 13
#     obs: 'cell_type'

# %%
z.write('../data/integrated/mofa/10xpbmc10k-mofa.h5ad')

# %%
# !rm '10xpbmc10k2020-expressions.h5ad'
# !rm '10xpbmc10k2020-peaks.h5ad'
# !rm '10xpbmc10k-mofa2.hdf5'
# Out:
# rm: cannot remove '10xpbmc10k2020-expressions.h5ad': No such file or directory
# rm: cannot remove '10xpbmc10k2020-peaks.h5ad': No such file or directory

# %% [markdown]
# ## Visualize results

# %%
sc.pp.neighbors(z)
sc.tl.umap(z)

# %%
sc.pl.umap(z, color='cell_type')
