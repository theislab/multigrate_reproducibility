# %%
import numpy as np
import scanpy as sc
import h5py
from mofapy2.run.entry_point import entry_point

# %% [markdown]
# # MOFA 2

# %% [markdown]
# ## Load the datasets

# %%
scrna = sc.read('../data/sagner-2021/expressions_hvg.h5ad')
scrna
# Out:
# AnnData object with n_obs × n_vars = 6334 × 4000
#     obs: 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'cell_type', 'batch'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells-0', 'n_cells_by_counts-0', 'mean_counts-0', 'log1p_mean_counts-0', 'pct_dropout_by_counts-0', 'total_counts-0', 'log1p_total_counts-0', 'highly_variable-0', 'means-0', 'dispersions-0', 'dispersions_norm-0', 'n_cells-1', 'n_cells_by_counts-1', 'mean_counts-1', 'log1p_mean_counts-1', 'pct_dropout_by_counts-1', 'total_counts-1', 'log1p_total_counts-1', 'highly_variable-1', 'means-1', 'dispersions-1', 'dispersions_norm-1', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg'
#     obsm: 'X_pca'
#     layers: 'count'

# %%
scrna1 = scrna[scrna.obs['batch'] == '0']
scrna2 = scrna[scrna.obs['batch'] == '1']

# %%
scrna1
# Out:
# View of AnnData object with n_obs × n_vars = 2859 × 4000
#     obs: 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'cell_type', 'batch'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells-0', 'n_cells_by_counts-0', 'mean_counts-0', 'log1p_mean_counts-0', 'pct_dropout_by_counts-0', 'total_counts-0', 'log1p_total_counts-0', 'highly_variable-0', 'means-0', 'dispersions-0', 'dispersions_norm-0', 'n_cells-1', 'n_cells_by_counts-1', 'mean_counts-1', 'log1p_mean_counts-1', 'pct_dropout_by_counts-1', 'total_counts-1', 'log1p_total_counts-1', 'highly_variable-1', 'means-1', 'dispersions-1', 'dispersions_norm-1', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg'
#     obsm: 'X_pca'
#     layers: 'count'

# %%
scrna2
# Out:
# View of AnnData object with n_obs × n_vars = 3475 × 4000
#     obs: 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'cell_type', 'batch'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells-0', 'n_cells_by_counts-0', 'mean_counts-0', 'log1p_mean_counts-0', 'pct_dropout_by_counts-0', 'total_counts-0', 'log1p_total_counts-0', 'highly_variable-0', 'means-0', 'dispersions-0', 'dispersions_norm-0', 'n_cells-1', 'n_cells_by_counts-1', 'mean_counts-1', 'log1p_mean_counts-1', 'pct_dropout_by_counts-1', 'total_counts-1', 'log1p_total_counts-1', 'highly_variable-1', 'means-1', 'dispersions-1', 'dispersions_norm-1', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg'
#     obsm: 'X_pca'
#     layers: 'count'

# %%
scatac = sc.read('../data/sagner-2020/peaks.h5ad')
scatac
# Out:
# AnnData object with n_obs × n_vars = 6334 × 38313
#     obs: 'nb_features', 'cell_type', 'batch'
#     var: 'feature_types', 'genome', 'gene_ids-0', 'n_cells-0', 'commonness-0', 'prop_shared_cells-0', 'variability_score-0', 'gene_ids-1', 'n_cells-1', 'commonness-1', 'prop_shared_cells-1', 'variability_score-1'
#     layers: 'binary'

# %%
scatac1 = scatac[scatac.obs['batch'] == '0']
scatac2 = scatac[scatac.obs['batch'] == '1']

# %% [markdown]
# ## Configure and train the model

# %%
ent = entry_point()
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################

# %%
ent.set_data_options(
    scale_groups = False, 
    scale_views = False
)

# %%
ent.set_data_matrix(
    [[scrna1.X.A, scrna2.X.A], [scatac1.X.A, scatac2.X.A]],
    views_names=['scRNA', 'scATAC'],
    groups_names=['batch_1', 'batch_2']
)
# Out:
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='scRNA' group='batch_1' with N=2859 samples and D=4000 features...
# Successfully loaded view='scRNA' group='batch_2' with N=3475 samples and D=4000 features...
# Successfully loaded view='scATAC' group='batch_1' with N=2859 samples and D=38313 features...
# Successfully loaded view='scATAC' group='batch_2' with N=3475 samples and D=38313 features...

# %%
ent.set_model_options(
    factors = 20, 
    spikeslab_weights = True, 
    ard_factors = True,
    ard_weights = True
)
# Out:
# Model options:
# - Automatic Relevance Determination prior on the factors: True
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (scRNA): gaussian
# - View 1 (scATAC): gaussian

# %%
ent.set_train_options(
    iter = 1000, 
    convergence_mode = "fast", 
    startELBO = 1, 
    freqELBO = 1, 
    dropR2 = 0.001, 
    gpu_mode = False, 
    verbose = False, 
    seed = 1
)

# %%
ent.build()

# %%
ent.run()
# Out:
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -325310555.30
#
# Iteration 1: time=336.76, ELBO=-23847487.08, deltaELBO=301463068.218 (92.66931654%), Factors=19
# Iteration 2: time=340.91, ELBO=-19486016.25, deltaELBO=4361470.826 (1.34070990%), Factors=18
# Iteration 3: time=311.41, ELBO=-18960587.81, deltaELBO=525428.448 (0.16151595%), Factors=17
# Iteration 4: time=293.11, ELBO=-18515487.54, deltaELBO=445100.262 (0.13682318%), Factors=16
# Iteration 5: time=276.67, ELBO=-18351370.63, deltaELBO=164116.912 (0.05044930%), Factors=15
# Iteration 6: time=264.48, ELBO=-18215528.52, deltaELBO=135842.115 (0.04175767%), Factors=14
# Iteration 7: time=243.08, ELBO=-18115026.76, deltaELBO=100501.758 (0.03089410%), Factors=13
# Iteration 8: time=255.94, ELBO=-18070124.88, deltaELBO=44901.877 (0.01380277%), Factors=13
# Iteration 9: time=245.71, ELBO=-18039577.99, deltaELBO=30546.892 (0.00939007%), Factors=13
# Iteration 10: time=247.70, ELBO=-18014113.14, deltaELBO=25464.852 (0.00782786%), Factors=13
# Iteration 11: time=239.82, ELBO=-17990056.96, deltaELBO=24056.175 (0.00739483%), Factors=13
# Iteration 12: time=304.27, ELBO=-17967884.81, deltaELBO=22172.149 (0.00681569%), Factors=13
# Iteration 13: time=430.75, ELBO=-17947925.34, deltaELBO=19959.477 (0.00613551%), Factors=13
# Iteration 15: time=370.49, ELBO=-17911291.84, deltaELBO=18061.887 (0.00555220%), Factors=13
# Iteration 16: time=411.97, ELBO=-17893708.18, deltaELBO=17583.659 (0.00540519%), Factors=13
# Iteration 17: time=341.21, ELBO=-17877112.19, deltaELBO=16595.998 (0.00510159%), Factors=13
# Iteration 18: time=420.30, ELBO=-17861584.41, deltaELBO=15527.780 (0.00477322%), Factors=13
# Iteration 19: time=429.30, ELBO=-17846686.90, deltaELBO=14897.506 (0.00457947%), Factors=13
# Iteration 20: time=411.78, ELBO=-17831759.20, deltaELBO=14927.704 (0.00458875%), Factors=13
# Iteration 21: time=430.36, ELBO=-17816128.89, deltaELBO=15630.302 (0.00480473%), Factors=13
# Iteration 22: time=422.45, ELBO=-17799111.83, deltaELBO=17017.059 (0.00523102%), Factors=13
# Iteration 23: time=318.46, ELBO=-17780331.85, deltaELBO=18779.986 (0.00577294%), Factors=13
# Iteration 24: time=252.26, ELBO=-17759977.46, deltaELBO=20354.392 (0.00625691%), Factors=13
# Iteration 25: time=240.28, ELBO=-17738751.31, deltaELBO=21226.144 (0.00652489%), Factors=13
# Iteration 26: time=242.02, ELBO=-17717665.38, deltaELBO=21085.934 (0.00648179%), Factors=13
# Iteration 29: time=244.41, ELBO=-17663343.83, deltaELBO=16083.870 (0.00494416%), Factors=13
# Iteration 30: time=239.28, ELBO=-17649120.59, deltaELBO=14223.240 (0.00437220%), Factors=13
# Iteration 31: time=243.56, ELBO=-17636041.14, deltaELBO=13079.451 (0.00402060%), Factors=13
# Iteration 32: time=238.05, ELBO=-17623464.33, deltaELBO=12576.808 (0.00386609%), Factors=13
# Iteration 33: time=246.85, ELBO=-17611110.05, deltaELBO=12354.277 (0.00379769%), Factors=13
# Iteration 34: time=236.73, ELBO=-17598998.71, deltaELBO=12111.345 (0.00372301%), Factors=13
# Iteration 36: time=258.70, ELBO=-17575922.25, deltaELBO=11319.087 (0.00347947%), Factors=13
# Iteration 37: time=242.63, ELBO=-17565138.92, deltaELBO=10783.332 (0.00331478%), Factors=13
# Iteration 38: time=240.97, ELBO=-17554997.00, deltaELBO=10141.916 (0.00311761%), Factors=13
# Iteration 39: time=268.47, ELBO=-17545549.72, deltaELBO=9447.282 (0.00290408%), Factors=13
# Iteration 40: time=241.68, ELBO=-17536880.80, deltaELBO=8668.919 (0.00266481%), Factors=13
# Iteration 41: time=249.96, ELBO=-17529229.94, deltaELBO=7650.856 (0.00235186%), Factors=13
# Iteration 42: time=248.40, ELBO=-17522917.07, deltaELBO=6312.873 (0.00194057%), Factors=13
# Iteration 43: time=236.53, ELBO=-17518094.02, deltaELBO=4823.048 (0.00148260%), Factors=13
# Iteration 44: time=243.42, ELBO=-17514604.06, deltaELBO=3489.961 (0.00107281%), Factors=13
# Iteration 45: time=240.03, ELBO=-17512098.36, deltaELBO=2505.697 (0.00077025%), Factors=13
# Iteration 46: time=244.91, ELBO=-17510228.58, deltaELBO=1869.788 (0.00057477%), Factors=13
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################

# %%
outfile = 'sagner-mofa2.hdf5'
ent.save(outfile)
# Out:
# Saving model in sagner-mofa2.hdf5...

# %% [markdown]
# ## Save results as AnnData

# %%
f = h5py.File(outfile)

# %%
z = np.concatenate([v[:,:] for k, v in f['expectations']['Z'].items()], axis=1).T
z = sc.AnnData(z)

z.obs_names = scrna.obs_names
z.obs = scrna.obs

z
# Out:
# AnnData object with n_obs × n_vars = 6334 × 13
#     obs: 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'cell_type', 'batch'

# %%
z.write('../data/integrated/mofa/sagner-mofa.h5ad')

# %%
# !rm 'sagner-mofa2.hdf5'

# %% [markdown]
# ## Visualize results

# %%
sc.pp.neighbors(z)
sc.tl.umap(z)

# %%
sc.pl.umap(z, color=['cell_type', 'batch'], ncols=1, frameon=False)
