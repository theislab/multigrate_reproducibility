# %%
x=1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
from anndata import AnnData
from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap
from plottable.plots import bar

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

def cmap_map(function, cmap):
    """ Applies function (which should operate on vectors of shape 3: [r, g, b]), on colormap cmap.
    This routine will break any discontinuous points in a colormap.
    """
    cdict = cmap._segmentdata
    step_dict = {}
    # Firt get the list of points where the segments start or end
    for key in ('red', 'green', 'blue'):
        step_dict[key] = list(map(lambda x: x[0], cdict[key]))
    step_list = sum(step_dict.values(), [])
    step_list = np.array(list(set(step_list)))
    # Then compute the LUT, and apply the function to the LUT
    reduced_cmap = lambda step : np.array(cmap(step)[0:3])
    old_LUT = np.array(list(map(reduced_cmap, step_list)))
    new_LUT = np.array(list(map(function, old_LUT)))
    # Now try to make a minimal segment definition of the new LUT
    cdict = {}
    for i, key in enumerate(['red','green','blue']):
        this_cdict = {}
        for j, step in enumerate(step_list):
            if step in step_dict[key]:
                this_cdict[step] = new_LUT[j, i]
            elif new_LUT[j,i] != old_LUT[j, i]:
                this_cdict[step] = new_LUT[j, i]
        colorvector = list(map(lambda x: x + (x[1], ), this_cdict.items()))
        colorvector.sort()
        cdict[key] = colorvector

    return matplotlib.colors.LinearSegmentedColormap('colormap',cdict,1024)

# %%
light_cmap = cmap_map(lambda x: x/2 + 0.5, matplotlib.cm.YlGnBu)

# %%
df_type = {
    'ARI': 'Bio conservation',
    'NMI': 'Bio conservation',
    'Label ASW': 'Bio conservation',
    'Isolated label ASW': 'Bio conservation',
    'Batch ASW': 'Batch correction',
    'Graph Connectivity': 'Batch correction',
    'Bio conservation': 'Aggregate score',
    'Batch correction': 'Aggregate score',
    'Total': 'Aggregate score',
}
df_type = pd.DataFrame(df_type, index=['Metric Type'])
df_type
# Out:
#                           ARI               NMI         Label ASW  \
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW         Batch ASW Graph Connectivity  \
# Metric Type   Bio conservation  Batch correction   Batch correction
#
#             Bio conservation Batch correction            Total
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %% [markdown]
# # Hao

# %%
df_mofa = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/MOFA+/hao_mofa_new.csv', index_col=0, header=0)
df_mofa = df_mofa.dropna()
df_mofa = df_mofa.T
df_mofa = df_mofa.rename(index={'0': 'MOFA+'})
df_mofa
# Out:
#        NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MOFA+           0.764907           0.625097    0.58269         0.774562
#
#        isolated_label_silhouette  graph_conn
# MOFA+                   0.585832    0.921138

# %%
df_multigrate = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/multigrate/multigrate_hao.csv', index_col=0, header=0)
df_multigrate = df_multigrate.dropna()
df_multigrate = df_multigrate.T
df_multigrate = df_multigrate.rename(index={'0': 'Multigrate'})
df_multigrate
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate           0.841413           0.792095   0.654312         0.891315
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.644881    0.950743

# %%
df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/code/recomb_multimodal_q2r/data/hao/0.001_embed.csv', index_col=0, header=0)
df_totalvi = df_totalvi.dropna()
df_totalvi = df_totalvi.T
df_totalvi = df_totalvi.rename(index={'0': 'totalVI'})
df_totalvi
# Out:
#          NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# totalVI           0.818238           0.679629   0.577603          0.93607
#
#          isolated_label_silhouette  graph_conn
# totalVI                   0.598906      0.9814

# %%
df_wnn = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/Seuratv4/hao-seurat.csv', index_col=0, header=0)
df_wnn = df_wnn.dropna()
df_wnn = df_wnn.T
df_wnn = df_wnn.rename(index={'0': 'Seurat WNN'})
df_wnn
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Seurat WNN           0.836297           0.704605   0.571911         0.877684
#
#             isolated_label_silhouette  graph_conn
# Seurat WNN                     0.5927     0.98399

# %%
df = pd.concat([df_multigrate, df_mofa, df_totalvi, df_wnn])
df
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate           0.841413           0.792095   0.654312         0.891315
# MOFA+                0.764907           0.625097   0.582690         0.774562
# totalVI              0.818238           0.679629   0.577603         0.936070
# Seurat WNN           0.836297           0.704605   0.571911         0.877684
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.644881    0.950743
# MOFA+                        0.585832    0.921138
# totalVI                      0.598906    0.981400
# Seurat WNN                   0.592700    0.983990

# %%
df = df.rename(columns={
    'NMI_cluster/label': 'NMI', 
    'ARI_cluster/label': 'ARI',
    'ASW_label': 'Label ASW',
    'ASW_label/batch': 'Batch ASW',
    'isolated_label_silhouette': 'Isolated label ASW',
    'graph_conn': 'Graph Connectivity',
})

# %%
df.loc[:, 'Bio conservation'] = np.mean([df.loc[:, 'ARI'], df.loc[:, 'NMI'], df.loc[:, 'Isolated label ASW'], df.loc[:, 'Label ASW']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.841413  0.792095   0.654312   0.891315            0.644881
# MOFA+       0.764907  0.625097   0.582690   0.774562            0.585832
# totalVI     0.818238  0.679629   0.577603   0.936070            0.598906
# Seurat WNN  0.836297  0.704605   0.571911   0.877684            0.592700
#
#             Graph Connectivity  Bio conservation
# Multigrate            0.950743          0.733176
# MOFA+                 0.921138          0.639632
# totalVI               0.981400          0.668594
# Seurat WNN            0.983990          0.676378

# %%
df.loc[:, 'Batch correction'] = np.mean([df.loc[:, 'Batch ASW'], df.loc[:, 'Graph Connectivity']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.841413  0.792095   0.654312   0.891315            0.644881
# MOFA+       0.764907  0.625097   0.582690   0.774562            0.585832
# totalVI     0.818238  0.679629   0.577603   0.936070            0.598906
# Seurat WNN  0.836297  0.704605   0.571911   0.877684            0.592700
#
#             Graph Connectivity  Bio conservation  Batch correction
# Multigrate            0.950743          0.733176          0.921029
# MOFA+                 0.921138          0.639632          0.847850
# totalVI               0.981400          0.668594          0.958735
# Seurat WNN            0.983990          0.676378          0.930837

# %%
df.loc[:, 'Total'] = 0.6 * df.loc[:, 'Bio conservation'] + 0.4 * df.loc[:, 'Batch correction']

# %%
df = pd.concat([df, df_type])

# %%
score_cols = df.columns[df.loc['Metric Type'] == 'Aggregate score']
other_cols = df.columns[df.loc['Metric Type'] != 'Aggregate score']

# %%
plot_df = df.drop('Metric Type', axis=0)

# %%
plot_df = plot_df.sort_values(by="Total", ascending=False).astype(np.float64)

# %%
plot_df["Method"] = plot_df.index

# %%
column_definitions = [
    ColumnDefinition("Method", width=1.5, textprops={"ha": "left", "weight": "bold"}),
]

# %%
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate           0.841413          0.792095          0.654312
# MOFA+                0.764907          0.625097           0.58269
# totalVI              0.818238          0.679629          0.577603
# Seurat WNN           0.836297          0.704605          0.571911
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#                     Batch ASW Isolated label ASW Graph Connectivity  \
# Multigrate           0.891315           0.644881           0.950743
# MOFA+                0.774562           0.585832           0.921138
# totalVI               0.93607           0.598906             0.9814
# Seurat WNN           0.877684             0.5927            0.98399
# Metric Type  Batch correction   Bio conservation   Batch correction
#
#             Bio conservation Batch correction            Total
# Multigrate          0.733176         0.921029         0.808317
# MOFA+               0.639632          0.84785         0.722919
# totalVI             0.668594         0.958735          0.78465
# Seurat WNN          0.676378         0.930837         0.778162
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
df = df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total']]
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate           0.841413          0.792095          0.654312
# MOFA+                0.764907          0.625097           0.58269
# totalVI              0.818238          0.679629          0.577603
# Seurat WNN           0.836297          0.704605          0.571911
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW         Batch ASW Graph Connectivity  \
# Multigrate            0.644881          0.891315           0.950743
# MOFA+                 0.585832          0.774562           0.921138
# totalVI               0.598906           0.93607             0.9814
# Seurat WNN              0.5927          0.877684            0.98399
# Metric Type   Bio conservation  Batch correction   Batch correction
#
#             Bio conservation Batch correction            Total
# Multigrate          0.733176         0.921029         0.808317
# MOFA+               0.639632          0.84785         0.722919
# totalVI             0.668594         0.958735          0.78465
# Seurat WNN          0.676378         0.930837         0.778162
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
plot_df = plot_df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total', 'Method']]
plot_df
# Out:
#                  NMI       ARI  Label ASW  Isolated label ASW  Batch ASW  \
# Multigrate  0.841413  0.792095   0.654312            0.644881   0.891315
# totalVI     0.818238  0.679629   0.577603            0.598906   0.936070
# Seurat WNN  0.836297  0.704605   0.571911            0.592700   0.877684
# MOFA+       0.764907  0.625097   0.582690            0.585832   0.774562
#
#             Graph Connectivity  Bio conservation  Batch correction     Total  \
# Multigrate            0.950743          0.733176          0.921029  0.808317
# totalVI               0.981400          0.668594          0.958735  0.784650
# Seurat WNN            0.983990          0.676378          0.930837  0.778162
# MOFA+                 0.921138          0.639632          0.847850  0.722919
#
#                 Method
# Multigrate  Multigrate
# totalVI        totalVI
# Seurat WNN  Seurat WNN
# MOFA+            MOFA+

# %%
plot_df.to_csv('csv/all_metrics_hao.csv')

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=matplotlib.cm.PRGn, num_stds=2.5)

# Circles for the metric values
column_definitions += [
    ColumnDefinition(
        col,
        title=col.replace(" ", "\n", 1),
        width=1,
        textprops={
            "ha": "center",
            "bbox": {"boxstyle": "circle", "pad": 0.25},
        },
        cmap=cmap_fn(plot_df[col]),
        group=df.loc['Metric Type', col],
        formatter="{:.2f}",
    )
    for i, col in enumerate(other_cols)
]

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=light_cmap, num_stds=2.5)

# Bars for the aggregate scores
column_definitions += [
    ColumnDefinition(
        col,
        width=1,
        title=col.replace(" ", "\n", 1),
        plot_fn=bar,
        plot_kw={
            "cmap": cmap_fn(plot_df[col]),
            "plot_bg_bar": False,
            "annotate": True,
            "height": 0.9,
            "formatter": "{:.2f}",
        },
        group=df.loc['Metric Type', col],
        border="left" if i == 0 else None,
    )
    for i, col in enumerate(score_cols)
]

# %%
num_embeds = len(plot_df)

# Allow to manipulate text post-hoc (in illustrator)
with matplotlib.rc_context({"svg.fonttype": "none"}):
    fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
    tab = Table(
        plot_df,
        cell_kw={
            "linewidth": 0,
            "edgecolor": "k",
        },
        column_definitions=column_definitions,
        ax=ax,
        row_dividers=True,
        footer_divider=True,
        textprops={"fontsize": 9, "ha": "center"},
        row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
        col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
        column_border_kw={"linewidth": 1, "linestyle": "-"},
        index_col="Method",
    ).autoset_fontcolors(colnames=plot_df.columns)

plt.savefig('figures/scib_table_hao.svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# # neurips cite

# %%
df_mofa = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/MOFA+/neurips_cite_mofa_new.csv', index_col=0, header=0)
df_mofa = df_mofa.dropna()
df_mofa = df_mofa.T
df_mofa = df_mofa.rename(index={'0': 'MOFA+'})
df_mofa
# Out:
#        NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MOFA+           0.640398           0.374594   0.570123         0.804016
#
#        isolated_label_silhouette  graph_conn
# MOFA+                   0.601662    0.844645

# %%
df_multigrate = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/multigrate/multigrate_neurips_cite.csv', index_col=0, header=0)
df_multigrate = df_multigrate.dropna()
df_multigrate = df_multigrate.T
df_multigrate = df_multigrate.rename(index={'0': 'Multigrate'})
df_multigrate
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate            0.79275            0.74074   0.607309         0.818657
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.643355    0.909775

# %%
df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/code/recomb_multimodal_q2r/data/neurips-cite/0.001_embed_leiden.csv', index_col=0, header=0)
df_totalvi = df_totalvi.dropna()
df_totalvi = df_totalvi.T
df_totalvi = df_totalvi.rename(index={'0': 'totalVI'})
df_totalvi
# Out:
#          NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# totalVI           0.800939           0.758088   0.570132         0.889003
#
#          isolated_label_silhouette  graph_conn
# totalVI                   0.624951    0.929448

# %%
df_wnn = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/Seuratv4/neurips-cite-seurat.csv', index_col=0, header=0)
df_wnn = df_wnn.dropna()
df_wnn = df_wnn.T
df_wnn = df_wnn.rename(index={'0': 'Seurat WNN'})
df_wnn
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Seurat WNN           0.759189           0.655493   0.573505         0.798508
#
#             isolated_label_silhouette  graph_conn
# Seurat WNN                   0.490371    0.915899

# %%
df = pd.concat([df_multigrate, df_mofa, df_totalvi, df_wnn])
df
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate           0.792750           0.740740   0.607309         0.818657
# MOFA+                0.640398           0.374594   0.570123         0.804016
# totalVI              0.800939           0.758088   0.570132         0.889003
# Seurat WNN           0.759189           0.655493   0.573505         0.798508
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.643355    0.909775
# MOFA+                        0.601662    0.844645
# totalVI                      0.624951    0.929448
# Seurat WNN                   0.490371    0.915899

# %%
df = df.rename(columns={
    'NMI_cluster/label': 'NMI', 
    'ARI_cluster/label': 'ARI',
    'ASW_label': 'Label ASW',
    'ASW_label/batch': 'Batch ASW',
    'isolated_label_silhouette': 'Isolated label ASW',
    'graph_conn': 'Graph Connectivity',
})

# %%
df.loc[:, 'Bio conservation'] = np.mean([df.loc[:, 'ARI'], df.loc[:, 'NMI'], df.loc[:, 'Isolated label ASW'], df.loc[:, 'Label ASW']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.792750  0.740740   0.607309   0.818657            0.643355
# MOFA+       0.640398  0.374594   0.570123   0.804016            0.601662
# totalVI     0.800939  0.758088   0.570132   0.889003            0.624951
# Seurat WNN  0.759189  0.655493   0.573505   0.798508            0.490371
#
#             Graph Connectivity  Bio conservation
# Multigrate            0.909775          0.696039
# MOFA+                 0.844645          0.546694
# totalVI               0.929448          0.688528
# Seurat WNN            0.915899          0.619639

# %%
df.loc[:, 'Batch correction'] = np.mean([df.loc[:, 'Batch ASW'], df.loc[:, 'Graph Connectivity']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.792750  0.740740   0.607309   0.818657            0.643355
# MOFA+       0.640398  0.374594   0.570123   0.804016            0.601662
# totalVI     0.800939  0.758088   0.570132   0.889003            0.624951
# Seurat WNN  0.759189  0.655493   0.573505   0.798508            0.490371
#
#             Graph Connectivity  Bio conservation  Batch correction
# Multigrate            0.909775          0.696039          0.864216
# MOFA+                 0.844645          0.546694          0.824331
# totalVI               0.929448          0.688528          0.909225
# Seurat WNN            0.915899          0.619639          0.857204

# %%
df.loc[:, 'Total'] = 0.6 * df.loc[:, 'Bio conservation'] + 0.4 * df.loc[:, 'Batch correction']

# %%
df = pd.concat([df, df_type])

# %%
score_cols = df.columns[df.loc['Metric Type'] == 'Aggregate score']
other_cols = df.columns[df.loc['Metric Type'] != 'Aggregate score']

# %%
plot_df = df.drop('Metric Type', axis=0)

# %%
plot_df = plot_df.sort_values(by="Total", ascending=False).astype(np.float64)

# %%
plot_df["Method"] = plot_df.index

# %%
column_definitions = [
    ColumnDefinition("Method", width=1.5, textprops={"ha": "left", "weight": "bold"}),
]

# %%
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate            0.79275           0.74074          0.607309
# MOFA+                0.640398          0.374594          0.570123
# totalVI              0.800939          0.758088          0.570132
# Seurat WNN           0.759189          0.655493          0.573505
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#                     Batch ASW Isolated label ASW Graph Connectivity  \
# Multigrate           0.818657           0.643355           0.909775
# MOFA+                0.804016           0.601662           0.844645
# totalVI              0.889003           0.624951           0.929448
# Seurat WNN           0.798508           0.490371           0.915899
# Metric Type  Batch correction   Bio conservation   Batch correction
#
#             Bio conservation Batch correction            Total
# Multigrate          0.696039         0.864216         0.763309
# MOFA+               0.546694         0.824331         0.657749
# totalVI             0.688528         0.909225         0.776807
# Seurat WNN          0.619639         0.857204         0.714665
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
df = df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total']]
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate            0.79275           0.74074          0.607309
# MOFA+                0.640398          0.374594          0.570123
# totalVI              0.800939          0.758088          0.570132
# Seurat WNN           0.759189          0.655493          0.573505
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW         Batch ASW Graph Connectivity  \
# Multigrate            0.643355          0.818657           0.909775
# MOFA+                 0.601662          0.804016           0.844645
# totalVI               0.624951          0.889003           0.929448
# Seurat WNN            0.490371          0.798508           0.915899
# Metric Type   Bio conservation  Batch correction   Batch correction
#
#             Bio conservation Batch correction            Total
# Multigrate          0.696039         0.864216         0.763309
# MOFA+               0.546694         0.824331         0.657749
# totalVI             0.688528         0.909225         0.776807
# Seurat WNN          0.619639         0.857204         0.714665
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
plot_df = plot_df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total', 'Method']]
plot_df
# Out:
#                  NMI       ARI  Label ASW  Isolated label ASW  Batch ASW  \
# totalVI     0.800939  0.758088   0.570132            0.624951   0.889003
# Multigrate  0.792750  0.740740   0.607309            0.643355   0.818657
# Seurat WNN  0.759189  0.655493   0.573505            0.490371   0.798508
# MOFA+       0.640398  0.374594   0.570123            0.601662   0.804016
#
#             Graph Connectivity  Bio conservation  Batch correction     Total  \
# totalVI               0.929448          0.688528          0.909225  0.776807
# Multigrate            0.909775          0.696039          0.864216  0.763309
# Seurat WNN            0.915899          0.619639          0.857204  0.714665
# MOFA+                 0.844645          0.546694          0.824331  0.657749
#
#                 Method
# totalVI        totalVI
# Multigrate  Multigrate
# Seurat WNN  Seurat WNN
# MOFA+            MOFA+

# %%
plot_df.to_csv('csv/all_metrics_neurips_cite.csv')

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=matplotlib.cm.PRGn, num_stds=2.5)

# Circles for the metric values
column_definitions += [
    ColumnDefinition(
        col,
        title=col.replace(" ", "\n", 1),
        width=1,
        textprops={
            "ha": "center",
            "bbox": {"boxstyle": "circle", "pad": 0.25},
        },
        cmap=cmap_fn(plot_df[col]),
        group=df.loc['Metric Type', col],
        formatter="{:.2f}",
    )
    for i, col in enumerate(other_cols)
]

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=light_cmap, num_stds=2.5)

# Bars for the aggregate scores
column_definitions += [
    ColumnDefinition(
        col,
        width=1,
        title=col.replace(" ", "\n", 1),
        plot_fn=bar,
        plot_kw={
            "cmap": cmap_fn(plot_df[col]),
            "plot_bg_bar": False,
            "annotate": True,
            "height": 0.9,
            "formatter": "{:.2f}",
        },
        group=df.loc['Metric Type', col],
        border="left" if i == 0 else None,
    )
    for i, col in enumerate(score_cols)
]

# %%
num_embeds = len(plot_df)

# Allow to manipulate text post-hoc (in illustrator)
with matplotlib.rc_context({"svg.fonttype": "none"}):
    fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
    tab = Table(
        plot_df,
        cell_kw={
            "linewidth": 0,
            "edgecolor": "k",
        },
        column_definitions=column_definitions,
        ax=ax,
        row_dividers=True,
        footer_divider=True,
        textprops={"fontsize": 9, "ha": "center"},
        row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
        col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
        column_border_kw={"linewidth": 1, "linestyle": "-"},
        index_col="Method",
    ).autoset_fontcolors(colnames=plot_df.columns)

plt.savefig('figures/scib_table_neurips_cite.svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# # neurips multiome

# %%
df_mofa = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/MOFA+/neurips_multiome_mofa_new.csv', index_col=0, header=0)
df_mofa = df_mofa.dropna()
df_mofa = df_mofa.T
df_mofa = df_mofa.rename(index={'0': 'MOFA+'})
df_mofa
# Out:
#        NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MOFA+           0.606385           0.258605   0.534082         0.813457
#
#        isolated_label_silhouette  graph_conn
# MOFA+                   0.604399    0.923153

# %%
df_multigrate = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/multigrate/multigrate_neurips_multiome_new_cpm.csv', index_col=0, header=0)
df_multigrate = df_multigrate.dropna()
df_multigrate = df_multigrate.T
df_multigrate = df_multigrate.rename(index={'0': 'Multigrate'})
df_multigrate
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate           0.784768            0.73276   0.593101         0.852988
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.673258    0.960074

# %%
df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/code/recomb_multimodal_q2r/data/neurips-multiome/0.001_embed.csv', index_col=0, header=0)
df_totalvi = df_totalvi.dropna()
df_totalvi = df_totalvi.T
df_totalvi = df_totalvi.rename(index={'0': 'multiVI'})
df_totalvi
# Out:
#          NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# multiVI           0.764233           0.680131   0.569681          0.86673
#
#          isolated_label_silhouette  graph_conn
# multiVI                   0.654425    0.959749

# %%
df_wnn = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/Seuratv4/neurips-multiome-seurat.csv', index_col=0, header=0)
df_wnn = df_wnn.dropna()
df_wnn = df_wnn.T
df_wnn = df_wnn.rename(index={'0': 'Seurat WNN'})
df_wnn
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Seurat WNN            0.77005           0.670767   0.590048         0.805851
#
#             isolated_label_silhouette  graph_conn
# Seurat WNN                   0.679805    0.970181

# %%
df = pd.concat([df_multigrate, df_mofa, df_totalvi, df_wnn])
df
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate           0.784768           0.732760   0.593101         0.852988
# MOFA+                0.606385           0.258605   0.534082         0.813457
# multiVI              0.764233           0.680131   0.569681         0.866730
# Seurat WNN           0.770050           0.670767   0.590048         0.805851
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.673258    0.960074
# MOFA+                        0.604399    0.923153
# multiVI                      0.654425    0.959749
# Seurat WNN                   0.679805    0.970181

# %%
df = df.rename(columns={
    'NMI_cluster/label': 'NMI', 
    'ARI_cluster/label': 'ARI',
    'ASW_label': 'Label ASW',
    'ASW_label/batch': 'Batch ASW',
    'isolated_label_silhouette': 'Isolated label ASW',
    'graph_conn': 'Graph Connectivity',
})

# %%
df.loc[:, 'Bio conservation'] = np.mean([df.loc[:, 'ARI'], df.loc[:, 'NMI'], df.loc[:, 'Isolated label ASW'], df.loc[:, 'Label ASW']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.784768  0.732760   0.593101   0.852988            0.673258
# MOFA+       0.606385  0.258605   0.534082   0.813457            0.604399
# multiVI     0.764233  0.680131   0.569681   0.866730            0.654425
# Seurat WNN  0.770050  0.670767   0.590048   0.805851            0.679805
#
#             Graph Connectivity  Bio conservation
# Multigrate            0.960074          0.695972
# MOFA+                 0.923153          0.500868
# multiVI               0.959749          0.667118
# Seurat WNN            0.970181          0.677668

# %%
df.loc[:, 'Batch correction'] = np.mean([df.loc[:, 'Batch ASW'], df.loc[:, 'Graph Connectivity']], axis=0)
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.784768  0.732760   0.593101   0.852988            0.673258
# MOFA+       0.606385  0.258605   0.534082   0.813457            0.604399
# multiVI     0.764233  0.680131   0.569681   0.866730            0.654425
# Seurat WNN  0.770050  0.670767   0.590048   0.805851            0.679805
#
#             Graph Connectivity  Bio conservation  Batch correction
# Multigrate            0.960074          0.695972          0.906531
# MOFA+                 0.923153          0.500868          0.868305
# multiVI               0.959749          0.667118          0.913239
# Seurat WNN            0.970181          0.677668          0.888016

# %%
df.loc[:, 'Total'] = 0.6 * df.loc[:, 'Bio conservation'] + 0.4 * df.loc[:, 'Batch correction']

# %%
df = pd.concat([df, df_type])

# %%
score_cols = df.columns[df.loc['Metric Type'] == 'Aggregate score']
other_cols = df.columns[df.loc['Metric Type'] != 'Aggregate score']

# %%
plot_df = df.drop('Metric Type', axis=0)

# %%
plot_df = plot_df.sort_values(by="Total", ascending=False).astype(np.float64)

# %%
plot_df["Method"] = plot_df.index

# %%
column_definitions = [
    ColumnDefinition("Method", width=1.5, textprops={"ha": "left", "weight": "bold"}),
]

# %%
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate           0.784768           0.73276          0.593101
# MOFA+                0.606385          0.258605          0.534082
# multiVI              0.764233          0.680131          0.569681
# Seurat WNN            0.77005          0.670767          0.590048
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#                     Batch ASW Isolated label ASW Graph Connectivity  \
# Multigrate           0.852988           0.673258           0.960074
# MOFA+                0.813457           0.604399           0.923153
# multiVI               0.86673           0.654425           0.959749
# Seurat WNN           0.805851           0.679805           0.970181
# Metric Type  Batch correction   Bio conservation   Batch correction
#
#             Bio conservation Batch correction            Total
# Multigrate          0.695972         0.906531         0.780196
# MOFA+               0.500868         0.868305         0.647843
# multiVI             0.667118         0.913239         0.765566
# Seurat WNN          0.677668         0.888016         0.761807
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
df = df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total']]
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate           0.784768           0.73276          0.593101
# MOFA+                0.606385          0.258605          0.534082
# multiVI              0.764233          0.680131          0.569681
# Seurat WNN            0.77005          0.670767          0.590048
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Isolated label ASW         Batch ASW Graph Connectivity  \
# Multigrate            0.673258          0.852988           0.960074
# MOFA+                 0.604399          0.813457           0.923153
# multiVI               0.654425           0.86673           0.959749
# Seurat WNN            0.679805          0.805851           0.970181
# Metric Type   Bio conservation  Batch correction   Batch correction
#
#             Bio conservation Batch correction            Total
# Multigrate          0.695972         0.906531         0.780196
# MOFA+               0.500868         0.868305         0.647843
# multiVI             0.667118         0.913239         0.765566
# Seurat WNN          0.677668         0.888016         0.761807
# Metric Type  Aggregate score  Aggregate score  Aggregate score

# %%
plot_df = plot_df.loc[:, ['NMI', 'ARI', 'Label ASW', 'Isolated label ASW', 'Batch ASW', 'Graph Connectivity', 'Bio conservation', 'Batch correction', 'Total', 'Method']]
plot_df
# Out:
#                  NMI       ARI  Label ASW  Isolated label ASW  Batch ASW  \
# Multigrate  0.784768  0.732760   0.593101            0.673258   0.852988
# multiVI     0.764233  0.680131   0.569681            0.654425   0.866730
# Seurat WNN  0.770050  0.670767   0.590048            0.679805   0.805851
# MOFA+       0.606385  0.258605   0.534082            0.604399   0.813457
#
#             Graph Connectivity  Bio conservation  Batch correction     Total  \
# Multigrate            0.960074          0.695972          0.906531  0.780196
# multiVI               0.959749          0.667118          0.913239  0.765566
# Seurat WNN            0.970181          0.677668          0.888016  0.761807
# MOFA+                 0.923153          0.500868          0.868305  0.647843
#
#                 Method
# Multigrate  Multigrate
# multiVI        multiVI
# Seurat WNN  Seurat WNN
# MOFA+            MOFA+

# %%
plot_df.to_csv('csv/all_metrics_neurips_multiome.csv')

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=matplotlib.cm.PRGn, num_stds=2.5)

# Circles for the metric values
column_definitions += [
    ColumnDefinition(
        col,
        title=col.replace(" ", "\n", 1),
        width=1,
        textprops={
            "ha": "center",
            "bbox": {"boxstyle": "circle", "pad": 0.25},
        },
        cmap=cmap_fn(plot_df[col]),
        group=df.loc['Metric Type', col],
        formatter="{:.2f}",
    )
    for i, col in enumerate(other_cols)
]

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=light_cmap, num_stds=2.5)

# Bars for the aggregate scores
column_definitions += [
    ColumnDefinition(
        col,
        width=1,
        title=col.replace(" ", "\n", 1),
        plot_fn=bar,
        plot_kw={
            "cmap": cmap_fn(plot_df[col]),
            "plot_bg_bar": False,
            "annotate": True,
            "height": 0.9,
            "formatter": "{:.2f}",
        },
        group=df.loc['Metric Type', col],
        border="left" if i == 0 else None,
    )
    for i, col in enumerate(score_cols)
]

# %%
num_embeds = len(plot_df)

# Allow to manipulate text post-hoc (in illustrator)
with matplotlib.rc_context({"svg.fonttype": "none"}):
    fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
    tab = Table(
        plot_df,
        cell_kw={
            "linewidth": 0,
            "edgecolor": "k",
        },
        column_definitions=column_definitions,
        ax=ax,
        row_dividers=True,
        footer_divider=True,
        textprops={"fontsize": 9, "ha": "center"},
        row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
        col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
        column_border_kw={"linewidth": 1, "linestyle": "-"},
        index_col="Method",
    ).autoset_fontcolors(colnames=plot_df.columns)

plt.savefig('figures/scib_table_neurips_multiome.svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# # 10x

# %%
df_mofa = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/MOFA+/10x_mofa_new.csv', index_col=0, header=0)
df_mofa = df_mofa.dropna()
df_mofa = df_mofa.T
df_mofa = df_mofa.rename(index={'0': 'MOFA+'})
df_mofa
# Out:
#        NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# MOFA+           0.791609           0.718718   0.632117         0.953821
#
#        isolated_label_silhouette  graph_conn
# MOFA+                   0.656029    0.992759

# %%
df_multigrate = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/multigrate/multigrate_10x_multiome.csv', index_col=0, header=0)
df_multigrate = df_multigrate.dropna()
df_multigrate = df_multigrate.T
df_multigrate = df_multigrate.rename(index={'0': 'Multigrate'})
df_multigrate
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate            0.79917           0.744534   0.674276         0.950534
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.684324    0.987826

# %%
df_totalvi = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/code/recomb_multimodal_q2r/data/10x/0.001_embed.csv', index_col=0, header=0)
df_totalvi = df_totalvi.dropna()
df_totalvi = df_totalvi.T
df_totalvi = df_totalvi.rename(index={'0': 'multiVI'})
df_totalvi
# Out:
#          NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# multiVI           0.795632            0.72338   0.637931         0.966903
#
#          isolated_label_silhouette  graph_conn
# multiVI                   0.666971    0.968455

# %%
df_wnn = pd.read_csv('/lustre/groups/ml01/workspace/anastasia.litinetskaya/notebooks/multigrate_integration/Seuratv4/10x-seurat.csv', index_col=0, header=0)
df_wnn = df_wnn.dropna()
df_wnn = df_wnn.T
df_wnn = df_wnn.rename(index={'0': 'Seurat WNN'})
df_wnn
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Seurat WNN            0.81687           0.749073   0.605977          0.96876
#
#             isolated_label_silhouette  graph_conn
# Seurat WNN                   0.639471    0.974883

# %%
df = pd.concat([df_multigrate, df_mofa, df_totalvi, df_wnn])
df
# Out:
#             NMI_cluster/label  ARI_cluster/label  ASW_label  ASW_label/batch  \
# Multigrate           0.799170           0.744534   0.674276         0.950534
# MOFA+                0.791609           0.718718   0.632117         0.953821
# multiVI              0.795632           0.723380   0.637931         0.966903
# Seurat WNN           0.816870           0.749073   0.605977         0.968760
#
#             isolated_label_silhouette  graph_conn
# Multigrate                   0.684324    0.987826
# MOFA+                        0.656029    0.992759
# multiVI                      0.666971    0.968455
# Seurat WNN                   0.639471    0.974883

# %%
df = df.rename(columns={
    'NMI_cluster/label': 'NMI', 
    'ARI_cluster/label': 'ARI',
    'ASW_label': 'Label ASW',
    'ASW_label/batch': 'Batch ASW',
    'isolated_label_silhouette': 'Isolated label ASW',
    'graph_conn': 'Graph Connectivity',
})

# %%
df.loc[:, 'Bio conservation'] = np.mean([df.loc[:, 'ARI'], df.loc[:, 'NMI'], df.loc[:, 'Label ASW']], axis=0) # no Isolated label ASW as no batch
df
# Out:
#                  NMI       ARI  Label ASW  Batch ASW  Isolated label ASW  \
# Multigrate  0.799170  0.744534   0.674276   0.950534            0.684324
# MOFA+       0.791609  0.718718   0.632117   0.953821            0.656029
# multiVI     0.795632  0.723380   0.637931   0.966903            0.666971
# Seurat WNN  0.816870  0.749073   0.605977   0.968760            0.639471
#
#             Graph Connectivity  Bio conservation
# Multigrate            0.987826          0.739327
# MOFA+                 0.992759          0.714148
# multiVI               0.968455          0.718981
# Seurat WNN            0.974883          0.723973

# %%
df.loc[:, 'Total'] = df.loc[:, 'Bio conservation']

# %%
df = pd.concat([df, df_type])

# %%
df = df.drop(['Graph Connectivity', 'Batch correction', 'Batch ASW', 'Isolated label ASW'], axis=1)
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate            0.79917          0.744534          0.674276
# MOFA+                0.791609          0.718718          0.632117
# multiVI              0.795632           0.72338          0.637931
# Seurat WNN            0.81687          0.749073          0.605977
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Bio conservation            Total
# Multigrate          0.739327         0.739327
# MOFA+               0.714148         0.714148
# multiVI             0.718981         0.718981
# Seurat WNN          0.723973         0.723973
# Metric Type  Aggregate score  Aggregate score

# %%
score_cols = df.columns[df.loc['Metric Type'] == 'Aggregate score']
other_cols = df.columns[df.loc['Metric Type'] != 'Aggregate score']

# %%
plot_df = df.drop('Metric Type', axis=0)

# %%
plot_df = plot_df.sort_values(by="Total", ascending=False).astype(np.float64)

# %%
plot_df["Method"] = plot_df.index

# %%
column_definitions = [
    ColumnDefinition("Method", width=1.5, textprops={"ha": "left", "weight": "bold"}),
]

# %%
df
# Out:
#                           NMI               ARI         Label ASW  \
# Multigrate            0.79917          0.744534          0.674276
# MOFA+                0.791609          0.718718          0.632117
# multiVI              0.795632           0.72338          0.637931
# Seurat WNN            0.81687          0.749073          0.605977
# Metric Type  Bio conservation  Bio conservation  Bio conservation
#
#             Bio conservation            Total
# Multigrate          0.739327         0.739327
# MOFA+               0.714148         0.714148
# multiVI             0.718981         0.718981
# Seurat WNN          0.723973         0.723973
# Metric Type  Aggregate score  Aggregate score

# %%
plot_df.to_csv('csv/all_metrics_10x.csv')

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=matplotlib.cm.PRGn, num_stds=2.5)

# Circles for the metric values
column_definitions += [
    ColumnDefinition(
        col,
        title=col.replace(" ", "\n", 1),
        width=1,
        textprops={
            "ha": "center",
            "bbox": {"boxstyle": "circle", "pad": 0.25},
        },
        cmap=cmap_fn(plot_df[col]),
        group=df.loc['Metric Type', col],
        formatter="{:.2f}",
    )
    for i, col in enumerate(other_cols)
]

# %%
cmap_fn = lambda col_data: normed_cmap(col_data, cmap=light_cmap, num_stds=2.5)

# Bars for the aggregate scores
column_definitions += [
    ColumnDefinition(
        col,
        width=1,
        title=col.replace(" ", "\n", 1),
        plot_fn=bar,
        plot_kw={
            "cmap": cmap_fn(plot_df[col]),
            "plot_bg_bar": False,
            "annotate": True,
            "height": 0.9,
            "formatter": "{:.2f}",
        },
        group=df.loc['Metric Type', col],
        border="left" if i == 0 else None,
    )
    for i, col in enumerate(score_cols)
]

# %%
num_embeds = len(plot_df)

# Allow to manipulate text post-hoc (in illustrator)
with matplotlib.rc_context({"svg.fonttype": "none"}):
    fig, ax = plt.subplots(figsize=(len(df.columns) * 1.25, 3 + 0.3 * num_embeds))
    tab = Table(
        plot_df,
        cell_kw={
            "linewidth": 0,
            "edgecolor": "k",
        },
        column_definitions=column_definitions,
        ax=ax,
        row_dividers=True,
        footer_divider=True,
        textprops={"fontsize": 9, "ha": "center"},
        row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
        col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
        column_border_kw={"linewidth": 1, "linestyle": "-"},
        index_col="Method",
    ).autoset_fontcolors(colnames=plot_df.columns)

plt.savefig('figures/scib_table_10x.svg', bbox_inches='tight')

plt.show()
